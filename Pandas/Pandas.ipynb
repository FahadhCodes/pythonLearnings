# %% [markdown]
# # Series

# %%
import pandas as pd
x = ["Apple","Orange","Banana"]
data = pd.Series(x)
print(data)

# %%
data = pd.Series(x,index=['A','B','C']) #Labeling
data

# %%
import pandas as pd
#reading dictionaries
std_data = {
    "Name":"Fahadh",
    "Age" : 24,
    "Course" : "Computer Science"
}

pd.Series(std_data) # return whole data
pd.Series(std_data,index = ["Name"]) #return only the name

# %% [markdown]
# # Data Frame

# %%
import pandas as pd
schedule = {
    "Name":["Light","Johan","Sung","Eren","Sukuna"],
    "Day":["Monday","Tuesday","Wednesday","Thursday","Friday"],
    "working_hour":[12,11,13,10,14]
}

df = pd.DataFrame(schedule)
print(df.loc[1]) # this returns pandas series formate
df

# %%
df = pd.DataFrame(schedule,index=["21APP1111","21APP1112","21APP1113","21APP1114","21APP1115"]) #labeling
print(df.loc["21APP1112"])
df

# %%
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

df

# %% [markdown]
# # Reading CSV files

# %%
import pandas as pd
df = pd.read_csv("std_performance.csv")
print(df) #print first and last five rows
print(df.to_string()) # print all rows
df = pd.option.display.max_rows = 999

df

# %%
import pandas as pd
df = pd.read_csv("std_performance.csv")
df.head(10) # Dispays first 10 rows
df.tail(10) # Displays last 10 rows
df.info() # Informatio of the dataset

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
df = pd.read_csv("std_performance.csv")
df.dropna(inplace = True)
df.loc[0,"Name"] = "Fahadh"
df.loc[0:6]

# %%
import pandas as pd
df = pd.read_csv("std_performance.csv")
#if we use .dropna() without inplace=True we have store it in a variable otherwise the cleaned dataset will be gone
df = df.dropna() 
df.loc[0,"Name"] = "Fahadh"
df.loc[0:6]

# %%
import pandas as pd 
df = pd.read_csv("std_performance.csv")
AttendanceRateAvg = f"{df["AttendanceRate"].mean():.2f}" # Taking mean of AttendanceRate and fill it using "fillna"
df = df.fillna({"AttendanceRate":AttendanceRateAvg})
df.loc[0:6]

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df['Date'] = pd.to_datetime(df['Date'], format='mixed')
print(df.to_string())

# %% [markdown]
# # Data Correlation

# %%
import pandas as pd
df = pd.read_csv("std_performance.csv")
#print(df.loc[4,"AttendanceRate"])
df

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("std_performance.csv")
# Mentionaning Necessary fields to clean null data contained recode
necessary_clm = ['StudyHoursPerWeek', 'PreviousGrade', 'ParentalSupport',
                 'FinalGrade', 'Study Hours', 'Attendance (%)', 'Online Classes Taken']
selected_fileds = [
    'StudyHoursPerWeek', 'PreviousGrade',
    'ExtracurricularActivities', 'ParentalSupport',
    'FinalGrade', 'Study Hours', 'Attendance (%)',
    'Online Classes Taken']


def cleaning(df, necessary_clm, selected_fileds):
    df = df.dropna(subset=necessary_clm)
    # Selecting fields
    df = df[selected_fileds]
    bdf = df.isna()
    # rechecking null
    for x in selected_fileds:
        print(f"_"*5, f"{x}", f"_"*5)
        for p, q in bdf[x].items():
            if q:
                message = "empty Available"
                print(f"{x}:{p, q, df.loc[p, x]}")
                if x == "ExtracurricularActivities":
                    df.fillna({x: 0}, inplace=True)
    return df


df = cleaning(df, necessary_clm, selected_fileds)
# other datatypes to numbers
df["ParentalSupport"] = df["ParentalSupport"].map({
    "High": 3,
    "Medium": 2,
    "Low": 1
})

df["Online Classes Taken"] = df["Online Classes Taken"].map({
    True: 1,
    False: 0
})


req = "Study Hours"
for x, y in df[req].items():
    if y < 0:
        df.loc[x, req] *= -1

print('''
info\t:1\n
describe\t:2\n
correlation\t:3\n
plotes\t:4\n
''')


def analytic():
    cho = int(input("Enter analytic type: "))
    if cho == 1:
        print(df.info())
    elif cho == 2:
        print(df.describe())
    elif cho == 3:
        print(df.corr())
    elif cho == 4:
        for column in selected_fileds:
            df.plot(kind="scatter", x=column, y="FinalGrade")
            plt.show()
analytic()
